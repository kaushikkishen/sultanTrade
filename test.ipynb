# %%
import pandas as pd
import os
from utils.change_column_names import changeToName
from utils.feature_engineering import *
from utils.data_loader import *

os.listdir()
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# %%
data = pd.read_csv('sample_tickdata.csv')
data.head()
# Out:
#    COLUMN01   COLUMN02  COLUMN03  COLUMN04  COLUMN05  COLUMN06  COLUMN07  \
# 0        20  002056.SZ  93000000    189600    189600    188900    189400
# 1        28  002056.SZ  93000000    189600    189600    188900    189400
# 2        39  002156.SZ  93000000    170900    171000    170500    170900
# 3        40  002156.SZ  93000000    170900    171000    170500    170900
# 4        63  002153.SZ  93000000    148000    148800    147900    147900
#
#    COLUMN08  COLUMN09  COLUMN10  COLUMN11  COLUMN12  COLUMN13  COLUMN14  \
# 0    189400    189500    189600    189900    190000    190200    190300
# 1    189400    189500    189600    189900    190000    190200    190300
# 2    171000    171200    171600    171800    171900    172000    172200
# 3    171000    171200    171600    171800    171900    172000    172200
# 4    148600    148700    148800    149500    149600    149800    149900
#
#    COLUMN15  COLUMN16  COLUMN17  COLUMN18  COLUMN19  COLUMN20  COLUMN21  \
# ...

# %%
data = changeToName(data)
data.head()
# Out:
#    Index  StockCode  TickTime  OpeningPrice  HighestPriceToTick  \
# 0     20  002056.SZ  93000000        189600              189600
# 1     28  002056.SZ  93000000        189600              189600
# 2     39  002156.SZ  93000000        170900              171000
# 3     40  002156.SZ  93000000        170900              171000
# 4     63  002153.SZ  93000000        148000              148800
#
#    LowestPriceToTick  LatestTransactionPriceToTick  SellingPrice1  \
# 0             188900                        189400         189400
# 1             188900                        189400         189400
# 2             170500                        170900         171000
# 3             170500                        170900         171000
# 4             147900                        147900         148600
#
#    SellingPrice2  SellingPrice3  SellingPrice4  SellingPrice5  SellingPrice6  \
# 0         189500         189600         189900         190000         190200
# ...

# %%
wa = NDayRegression()
datax = wa.transform(data)

# %%
datax.sort_values(['StockCode', 'TickTime']).head(20)[["LatestTransactionPriceToTick", '5_reg']]
# Out:
#      LatestTransactionPriceToTick  5_reg
# 60                          38600    NaN
# 61                          38600    NaN
# 114                         38400    NaN
# 148                         38400    NaN
# 214                         38500    NaN
# 264                         38500  -10.0
# 309                         38500   30.0
# 364                         38500   20.0
# 382                         38500    0.0
# 433                         38400  -20.0
# 518                         38400  -30.0
# 548                         38500  -10.0
# 615                         38500   10.0
# 648                         38500   30.0
# 716                         38500   20.0
# 761                         38400  -20.0
# 814                         38400  -30.0
# 862                         38400  -30.0
# 911                         38300  -40.0
# 961                         38300  -30.0

# %%
data[data['StockCode'] == '000031.SZ']
# Out:
#           Index  StockCode   TickTime  OpeningPrice  HighestPriceToTick  \
# 60          547  000031.SZ   93000000         38300               38600
# 61          548  000031.SZ   93000000         38300               38600
# 114        1093  000031.SZ   93003000         38300               38700
# 148        1461  000031.SZ   93006000         38300               38700
# 214        2105  000031.SZ   93009000         38300               38700
# ...         ...        ...        ...           ...                 ...
# 216341  2131533  000031.SZ  145933000         38300               38700
# 216424  2132368  000031.SZ  145942000         38300               38700
# 216523  2133370  000031.SZ  145951000         38300               38700
# 216653  2134611  000031.SZ  150000000         38300               38700
# 216654  2134612  000031.SZ  150000000         38300               38700
#
#         LowestPriceToTick  LatestTransactionPriceToTick  SellingPrice1  \
# ...

# %%
data.sort_values('TickTime').groupby('StockCode').rolling(5)['Index'].apply(lambda x: print(x))
# Out:
# 0      547.0
# 36     548.0
# 37    1093.0
# 38    1461.0
# 39    2105.0
# dtype: float64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 data.sort_values('TickTime').groupby('StockCode').rolling(5)['Index'].apply(lambda x: print(x))
#
# File ~\Anaconda3\lib\site-packages\pandas\core\window\rolling.py:1843, in Rolling.apply(self, func, raw, engine, engine_kwargs, args, kwargs)
#    1822 @doc(
#    1823     template_header,
#    1824     create_section_header("Parameters"),
#    (...)
#    1841     kwargs: dict[str, Any] | None = None,
#    1842 ):
# -> 1843     return super().apply(
#    1844         func,
#    1845         raw=raw,
#    1846         engine=engine,
#    1847         engine_kwargs=engine_kwargs,
#    1848         args=args,
#    1849         kwargs=kwargs,
#    1850     )
#
# ...

# %%
func = NDayRegression().n_day_regression
vecfunc = np.vectorize(lambda x:
if type(x) == str:
    x
else:
    func)
# Out:
#   Input In [8]
#     if type(x) == str:
#     ^
# SyntaxError: invalid syntax

# %%
vecfunc(data.groupby('StockCode'))

# %%
import inspect
inspect.getmembers(data.groupby('StockCode'))
