# %%
import pandas as pd
import os
from utils.change_column_names import changeToName
from utils.feature_engineering import *
from utils.labels import *
from utils.pipelines import transformation_pipeline

os.listdir()
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline

# %%
data = pd.read_csv('sample_tickdata.csv')
data.head()
# Out:
#    COLUMN01   COLUMN02  COLUMN03  COLUMN04  COLUMN05  COLUMN06  COLUMN07  \
# 0        20  002056.SZ  93000000    189600    189600    188900    189400
# 1        28  002056.SZ  93000000    189600    189600    188900    189400
# 2        39  002156.SZ  93000000    170900    171000    170500    170900
# 3        40  002156.SZ  93000000    170900    171000    170500    170900
# 4        63  002153.SZ  93000000    148000    148800    147900    147900
#
#    COLUMN08  COLUMN09  COLUMN10  COLUMN11  COLUMN12  COLUMN13  COLUMN14  \
# 0    189400    189500    189600    189900    190000    190200    190300
# 1    189400    189500    189600    189900    190000    190200    190300
# 2    171000    171200    171600    171800    171900    172000    172200
# 3    171000    171200    171600    171800    171900    172000    172200
# 4    148600    148700    148800    149500    149600    149800    149900
#
#    COLUMN15  COLUMN16  COLUMN17  COLUMN18  COLUMN19  COLUMN20  COLUMN21  \
# ...

# %%
data = changeToName(data)
data.head()
# Out:
#    Index  StockCode  TickTime  OpeningPrice  HighestPriceToTick  \
# 0     20  002056.SZ  93000000        189600              189600
# 1     28  002056.SZ  93000000        189600              189600
# 2     39  002156.SZ  93000000        170900              171000
# 3     40  002156.SZ  93000000        170900              171000
# 4     63  002153.SZ  93000000        148000              148800
#
#    LowestPriceToTick  LatestTransactionPriceToTick  SellingPrice1  \
# 0             188900                        189400         189400
# 1             188900                        189400         189400
# 2             170500                        170900         171000
# 3             170500                        170900         171000
# 4             147900                        147900         148600
#
#    SellingPrice2  SellingPrice3  SellingPrice4  SellingPrice5  SellingPrice6  \
# 0         189500         189600         189900         190000         190200
# ...

# %%
transformer = NDayRegression()
reg_data = transformer.transform(data)
reg_data.tail(15)
# Out:
#           Index  StockCode   TickTime  OpeningPrice  HighestPriceToTick  \
# 216610  2134237  300024.SZ  150000000         88300               89900
# 216611  2134243  300136.SZ  150000000        163000              165100
# 216612  2134247  300024.SZ  150000000         88300               89900
# 216613  2134251  300003.SZ  150000000        223600              230100
# 216614  2134252  300003.SZ  150000000        223600              230100
# 216615  2134271  002468.SZ  150000000        101300              104800
# 216616  2134272  002468.SZ  150000000        101300              104800
# 216617  2134279  002505.SZ  150000000         25100               25300
# 216618  2134280  002505.SZ  150000000         25100               25300
# 216619  2134282  002508.SZ  150000000        282000              282000
# 216620  2134283  002439.SZ  150000000        249100              261900
# 216621  2134291  002439.SZ  150000000        249100              261900
# ...

# %%
temp = reg_data[reg_data['StockCode'] == '300024.SZ'].sort_values('TickTime')
temp.head(15)
# Out:
#      Index  StockCode  TickTime  OpeningPrice  HighestPriceToTick  \
# 16     210  300024.SZ  93000000         88300               88600
# 19     220  300024.SZ  93000000         88300               88600
# 94     925  300024.SZ  93003000         88300               88700
# 138   1374  300024.SZ  93006000         88300               88900
# 189   1880  300024.SZ  93009000         88300               89400
# 240   2380  300024.SZ  93012000         88300               89400
# 290   2873  300024.SZ  93015000         88300               89400
# 342   3381  300024.SZ  93018000         88300               89400
# 388   3853  300024.SZ  93021000         88300               89400
# 438   4354  300024.SZ  93024000         88300               89400
# 495   4926  300024.SZ  93027000         88300               89500
# 539   5368  300024.SZ  93030000         88300               89500
# 599   5938  300024.SZ  93033000         88300               89500
# ...

# %%
data = transformation_pipeline.fit_transform(data)
data.head()
# Out:
#      StockCode  Index  TickTime  OpeningPrice  HighestPriceToTick  \
# 0    002056.SZ     20  93000000        189600              189600
# 1    002056.SZ     28  93000000        189600              189600
# 83   002056.SZ    776  93003000        189600              189600
# 128  002056.SZ   1257  93006000        189600              189600
# 180  002056.SZ   1776  93009000        189600              189600
#
#      LowestPriceToTick  LatestTransactionPriceToTick  SellingPrice1  \
# 0               188900                        189400         189400
# 1               188900                        189400         189400
# 83              188900                        189400         189500
# 128             188900                        189400         189400
# 180             188900                        189300         189300
#
#      SellingPrice2  SellingPrice3  SellingPrice4  SellingPrice5  \
# 0           189500         189600         189900         190000
# ...

# %%
X = data.drop('Label', axis=1)
y = data['Label']

# %%
model = Pipeline(steps=[
        ('OneHotEncode', OneHotEncoder()),
        ('Classifier', RandomForestClassifier())
        ])

# %%
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 model.fit(X, y)
#
# File ~\Anaconda3\lib\site-packages\sklearn\pipeline.py:382, in Pipeline.fit(self, X, y, **fit_params)
#     380     if self._final_estimator != "passthrough":
#     381         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 382         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     384 return self
#
# File ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:476, in BaseForest.fit(self, X, y, sample_weight)
#     465 trees = [
#     466     self._make_estimator(append=False, random_state=random_state)
#     467     for i in range(n_more_estimators)
#     468 ]
#     470 # Parallel loop: we prefer the threading backend as the Cython code
#     471 # for fitting the trees is internally releasing the Python GIL
# ...
