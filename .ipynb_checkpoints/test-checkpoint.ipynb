# %%
import pandas as pd
import os
from utils.change_column_names import changeToName
from utils.feature_engineering import *
from utils.labels import *

os.listdir()
# Out:
# ['.git',
#  '.idea',
#  '.ipynb_checkpoints',
#  'evaluation.py',
#  'myModel_demo.py',
#  'README.md',
#  'readme.txt',
#  'run.sh',
#  'sample_tickdata.csv',
#  'test.ipynb',
#  'train.py',
#  'utils']

# %%
data = pd.read_csv('sample_tickdata.csv')
data.head()
# Out:
#    Unnamed: 0  COLUMN01   COLUMN02  COLUMN03  COLUMN04  COLUMN05  COLUMN06  \
# 0          20        20  002056.SZ  93000000    189600    189600    188900
# 1          28        28  002056.SZ  93000000    189600    189600    188900
# 2          39        39  002156.SZ  93000000    170900    171000    170500
# 3          40        40  002156.SZ  93000000    170900    171000    170500
# 4          63        63  002153.SZ  93000000    148000    148800    147900
#
#    COLUMN07  COLUMN08  COLUMN09  COLUMN10  COLUMN11  COLUMN12  COLUMN13  \
# 0    189400    189400    189500    189600    189900    190000    190200
# 1    189400    189400    189500    189600    189900    190000    190200
# 2    170900    171000    171200    171600    171800    171900    172000
# 3    170900    171000    171200    171600    171800    171900    172000
# 4    147900    148600    148700    148800    149500    149600    149800
#
#    COLUMN14  COLUMN15  COLUMN16  COLUMN17  COLUMN18  COLUMN19  COLUMN20  \
# ...

# %%
data = changeToName(data)
data.head()
# Out:
#    Unnamed: 0  Index  StockCode  TickTime  OpeningPrice  HighestPriceToTick  \
# 0          20     20  002056.SZ  93000000        189600              189600
# 1          28     28  002056.SZ  93000000        189600              189600
# 2          39     39  002156.SZ  93000000        170900              171000
# 3          40     40  002156.SZ  93000000        170900              171000
# 4          63     63  002153.SZ  93000000        148000              148800
#
#    LowestPriceToTick  LatestTransactionPriceToTick  SellingPrice1  \
# 0             188900                        189400         189400
# 1             188900                        189400         189400
# 2             170500                        170900         171000
# 3             170500                        170900         171000
# 4             147900                        147900         148600
#
#    SellingPrice2  SellingPrice3  SellingPrice4  SellingPrice5  SellingPrice6  \
# ...

# %%
wa = TransactionVolume()
datax = wa.transform(data)

# %%
datax[datax['StockCode'] == '600536.SH'].sort_values(['StockCode', 'TickTime']) \
    [['StockCode', 'TickTime', 'CumulativeTransactionVolumeToTick',
     'TransactionVolume']].head(50)
# Out:
#        StockCode  TickTime  CumulativeTransactionVolumeToTick  \
# 0      600536.SH  93000000                              81500
# 667    600536.SH  93002000                             104650
# 1226   600536.SH  93005000                             112050
# 1728   600536.SH  93008000                             126550
# 2228   600536.SH  93011000                             157350
# 2712   600536.SH  93014000                             165750
# 3224   600536.SH  93017000                             181250
# 3701   600536.SH  93020000                             212550
# 4183   600536.SH  93023000                             246150
# 4770   600536.SH  93026000                             253850
# 5187   600536.SH  93029000                             263850
# 5779   600536.SH  93032000                             300150
# 6212   600536.SH  93035000                             333450
# 6714   600536.SH  93038000                             345350
# ...
